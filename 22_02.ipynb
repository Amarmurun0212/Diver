# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Diver/blob/main/22_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot((0,1,2,3,4,5),(2,5,3,7,6,1))
plt.title('Первый график')
plt.xlabel('ось Х')
plt.ylabel('ось У')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,100,1000)
y=x**3-x**2+x+1
plt.plot(x,y,'--r')
plt.show()
