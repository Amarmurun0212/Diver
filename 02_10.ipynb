# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Diver/blob/main/02_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.scatter((1,2,3,4,5,6),(4,8,5,9,4,0),c='r') #точечный график
plt.plot((10,2,5,6,7,0),'b--') #линейный график
plt.title("Графики") # имя графика
plt.xlabel(" Ось х")
plt.ylabel(" Ось y")
plt.grid() # сетка
plt.show() # показать график

# %%
import numpy as np
chisloPi = np.pi
print(np.sin(chisloPi))
# Out:
# 1.2246467991473532e-16

# %%
x = np.linspace(0,100,100) # массив 0-100 кол.точек=100
y = x**3+5*x**2+12
plt.plot(x,y,'r')
plt.title(' Функция y = x^3+5*x^2+12')
plt.show()

# %%
L = 10000
t = 6300
v = 3.3333333
x = np.linspace(-2,2,5)
x1 = np.arange(-2,3,1)
print(x)
print(x1)
# Out:
# [-2. -1.  0.  1.  2.]
# [-2 -1  0  1  2]
