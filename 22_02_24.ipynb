# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarmurun0212/Diver/blob/main/22_02_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot((0,1,2,3,4,5),(2,5,7,3,4,9))
plt.title('первый график')
plt.xlabel('ось х')
plt.ylabel('ось y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,15,100)
y=x**3+2*x**2-4*x+5
plt.plot(x,y,'r')
plt.scatter(8,3000,c='#0a0a0a')
plt.show()
